# %%
import pandas as pd;

# %%
import numpy as np;

# %% [markdown]
# - .head() returns the first few rows (the “head” of the DataFrame).
# - .info() shows information on each of the columns, such as the data type and number of missing values.
# - .shape returns the number of rows and columns of the DataFrame.
# - .describe() calculates a few summary statistics for each column.
# - .values: A two-dimensional NumPy array of values.
# - .columns: An index of columns: the column names.
# - .index: An index for the rows: either row numbers or row names

# %%
df= pd.read_csv("../../datasets/homelessness.csv")

# %%
df
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
df.values
# Out:
# array([[0, 'East South Central', 'Alabama', 2570.0, 864.0, 4887681],
#        [1, 'Pacific', 'Alaska', 1434.0, 582.0, 735139],
#        [2, 'Mountain', 'Arizona', 7259.0, 2606.0, 7158024],
#        [3, 'West South Central', 'Arkansas', 2280.0, 432.0, 3009733],
#        [4, 'Pacific', 'California', 109008.0, 20964.0, 39461588],
#        [5, 'Mountain', 'Colorado', 7607.0, 3250.0, 5691287],
#        [6, 'New England', 'Connecticut', 2280.0, 1696.0, 3571520],
#        [7, 'South Atlantic', 'Delaware', 708.0, 374.0, 965479],
#        [8, 'South Atlantic', 'District of Columbia', 3770.0, 3134.0,
#         701547],
#        [9, 'South Atlantic', 'Florida', 21443.0, 9587.0, 21244317],
#        [10, 'South Atlantic', 'Georgia', 6943.0, 2556.0, 10511131],
#        [11, 'Pacific', 'Hawaii', 4131.0, 2399.0, 1420593],
#        [12, 'Mountain', 'Idaho', 1297.0, 715.0, 1750536],
#        [13, 'East North Central', 'Illinois', 6752.0, 3891.0, 12723071],
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0    individuals  family_members     state_pop
# count   51.000000      51.000000       51.000000  5.100000e+01
# mean    25.000000    7225.784314     3504.882353  6.405637e+06
# std     14.866069   15991.025083     7805.411811  7.327258e+06
# min      0.000000     434.000000       75.000000  5.776010e+05
# 25%     12.500000    1446.500000      592.000000  1.777414e+06
# 50%     25.000000    3082.000000     1482.000000  4.461153e+06
# 75%     37.500000    6781.500000     3196.000000  7.340946e+06
# max     50.000000  109008.000000    52070.000000  3.946159e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     object
#  2   state           51 non-null     object
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.5+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
df['region']
# Out:
# 0     East South Central
# 1                Pacific
# 2               Mountain
# 3     West South Central
# 4                Pacific
# 5               Mountain
# 6            New England
# 7         South Atlantic
# 8         South Atlantic
# 9         South Atlantic
# 10        South Atlantic
# 11               Pacific
# 12              Mountain
# 13    East North Central
# 14    East North Central
# 15    West North Central
# 16    West North Central
# 17    East South Central
# 18    West South Central
# 19           New England
# 20        South Atlantic
# 21           New England
# 22    East North Central
# 23    West North Central
# 24    East South Central
# 25    West North Central
# 26              Mountain
# 27    West North Central
# 28              Mountain
# 29           New England
# 30          Mid-Atlantic
# 31              Mountain
# 32          Mid-Atlantic
# 33        South Atlantic
# 34    West North Central
# 35    East North Central
# 36    West South Central
# ...

# %%
df[['state','region']]
# Out:
#                    state              region
# 0                Alabama  East South Central
# 1                 Alaska             Pacific
# 2                Arizona            Mountain
# 3               Arkansas  West South Central
# 4             California             Pacific
# 5               Colorado            Mountain
# 6            Connecticut         New England
# 7               Delaware      South Atlantic
# 8   District of Columbia      South Atlantic
# 9                Florida      South Atlantic
# 10               Georgia      South Atlantic
# 11                Hawaii             Pacific
# 12                 Idaho            Mountain
# 13              Illinois  East North Central
# 14               Indiana  East North Central
# 15                  Iowa  West North Central
# 16                Kansas  West North Central
# 17              Kentucky  East South Central
# 18             Louisiana  West South Central
# 19                 Maine         New England
# ...

# %%
head=df.head()

# %%
head
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
type(head)
# Out:
# pandas.core.frame.DataFrame

# %%
head.sort_values('region')
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 4           4             Pacific  California     109008.0         20964.0
# 3           3  West South Central    Arkansas       2280.0           432.0
#
#    state_pop
# 0    4887681
# 2    7158024
# 1     735139
# 4   39461588
# 3    3009733

# %%
head.sort_values('region',ascending=False)
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 3           3  West South Central    Arkansas       2280.0           432.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 4           4             Pacific  California     109008.0         20964.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 0           0  East South Central     Alabama       2570.0           864.0
#
#    state_pop
# 3    3009733
# 1     735139
# 4   39461588
# 2    7158024
# 0    4887681

# %%
head.sort_values(['individuals','family_members'],ascending=[False,True])
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 4           4             Pacific  California     109008.0         20964.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 0           0  East South Central     Alabama       2570.0           864.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 1           1             Pacific      Alaska       1434.0           582.0
#
#    state_pop
# 4   39461588
# 2    7158024
# 0    4887681
# 3    3009733
# 1     735139

# %%
twenty= df.head(25)

# %%
twenty
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %%
twenty[['region','state_pop']]
# Out:
#                 region  state_pop
# 0   East South Central    4887681
# 1              Pacific     735139
# 2             Mountain    7158024
# 3   West South Central    3009733
# 4              Pacific   39461588
# 5             Mountain    5691287
# 6          New England    3571520
# 7       South Atlantic     965479
# 8       South Atlantic     701547
# 9       South Atlantic   21244317
# 10      South Atlantic   10511131
# 11             Pacific    1420593
# 12            Mountain    1750536
# 13  East North Central   12723071
# 14  East North Central    6695497
# 15  West North Central    3148618
# 16  West North Central    2911359
# 17  East South Central    4461153
# 18  West South Central    4659690
# 19         New England    1339057
# 20      South Atlantic    6035802
# 21         New England    6882635
# 22  East North Central    9984072
# 23  West North Central    5606249
# 24  East South Central    2981020

# %%
twenty['region']
# Out:
# 0     East South Central
# 1                Pacific
# 2               Mountain
# 3     West South Central
# 4                Pacific
# 5               Mountain
# 6            New England
# 7         South Atlantic
# 8         South Atlantic
# 9         South Atlantic
# 10        South Atlantic
# 11               Pacific
# 12              Mountain
# 13    East North Central
# 14    East North Central
# 15    West North Central
# 16    West North Central
# 17    East South Central
# 18    West South Central
# 19           New England
# 20        South Atlantic
# 21           New England
# 22    East North Central
# 23    West North Central
# 24    East South Central
# Name: region, dtype: object

# %%
twenty.sort_values('region',ascending=False)
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 18          18  West South Central             Louisiana       2540.0
# 3            3  West South Central              Arkansas       2280.0
# 16          16  West North Central                Kansas       1443.0
# 15          15  West North Central                  Iowa       1711.0
# 23          23  West North Central             Minnesota       3993.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 20          20      South Atlantic              Maryland       4914.0
# 10          10      South Atlantic               Georgia       6943.0
# 9            9      South Atlantic               Florida      21443.0
# 7            7      South Atlantic              Delaware        708.0
# 11          11             Pacific                Hawaii       4131.0
# 1            1             Pacific                Alaska       1434.0
# ...

# %%
twenty
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %%
twenty['Unnamed: 0'] > 15
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# Name: Unnamed: 0, dtype: bool

# %%
twenty[twenty['Unnamed: 0'] > 15]
# Out:
#     Unnamed: 0              region          state  individuals  \
# 16          16  West North Central         Kansas       1443.0
# 17          17  East South Central       Kentucky       2735.0
# 18          18  West South Central      Louisiana       2540.0
# 19          19         New England          Maine       1450.0
# 20          20      South Atlantic       Maryland       4914.0
# 21          21         New England  Massachusetts       6811.0
# 22          22  East North Central       Michigan       5209.0
# 23          23  West North Central      Minnesota       3993.0
# 24          24  East South Central    Mississippi       1024.0
#
#     family_members  state_pop
# 16           773.0    2911359
# 17           953.0    4461153
# 18           519.0    4659690
# 19          1066.0    1339057
# 20          2230.0    6035802
# 21         13257.0    6882635
# 22          3142.0    9984072
# 23          3250.0    5606249
# 24           328.0    2981020

# %%
first = twenty['state']=="Louisiana"

# %%
second = twenty['individuals'] > 1000;

# %%
twenty[first & second]
# Out:
#     Unnamed: 0              region      state  individuals  family_members  \
# 18          18  West South Central  Louisiana       2540.0           519.0
#
#     state_pop
# 18    4659690

# %%
states= ['Michigan','Minnesota','Mississippi']

# %%
states= twenty['state'].isin(states)

# %%
twenty[states]
# Out:
#     Unnamed: 0              region        state  individuals  family_members  \
# 22          22  East North Central     Michigan       5209.0          3142.0
# 23          23  West North Central    Minnesota       3993.0          3250.0
# 24          24  East South Central  Mississippi       1024.0           328.0
#
#     state_pop
# 22    9984072
# 23    5606249
# 24    2981020

# %%
twenty
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %%
twenty['BoolPop'] = twenty['state_pop'] < 40000;
# Out:
# <ipython-input-52-f4b8e8d09a47>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twenty['BoolPop'] = twenty['state_pop'] < 40000;

# %%
twenty
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

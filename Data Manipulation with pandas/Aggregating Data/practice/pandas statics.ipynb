# %%
import pandas as pd;
import numpy as np;

# %%
data= pd.read_csv("../../datasets/sales_subset.csv");

# %%
data
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 1               1      1    A           1  2010-03-05      21827.90
# 2               2      1    A           1  2010-04-02      57258.43
# 3               3      1    A           1  2010-05-07      17413.94
# 4               4      1    A           1  2010-06-04      17558.09
# ...           ...    ...  ...         ...         ...           ...
# 10769       10769     39    A          99  2011-12-09        895.00
# 10770       10770     39    A          99  2012-02-03        350.00
# 10771       10771     39    A          99  2012-06-08        450.00
# 10772       10772     39    A          99  2012-07-13          0.06
# 10773       10773     39    A          99  2012-10-05        915.00
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
data['weekly_sales'].min()
# Out:
# -1098.0

# %%
data['weekly_sales'].max()
# Out:
# 293966.05

# %%
data['weekly_sales'].sum()
# Out:
# 256894718.89999998

# %%
data['weekly_sales'].median()
# Out:
# 12049.064999999999

# %%
data['weekly_sales'].mean()
# Out:
# 23843.95014850566

# %%
data['weekly_sales'].std()
# Out:
# 30220.387556900612

# %%
data['weekly_sales'].var()
# Out:
# 913271824.0892733

# %%
data['weekly_sales'].mode()
# Out:
# 0    12.0
# dtype: float64

# %%
def in2(column):
    return sum(column)*2

# %%
data['weekly_sales'].agg(in2)
# Out:
# 513789437.80000013

# %%
data.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
data[['weekly_sales','fuel_price_usd_per_l']].agg(in2)
# Out:
# weekly_sales            5.137894e+08
# fuel_price_usd_per_l    1.615552e+04
# dtype: float64

# %%
def in3(column):
    return sum(column)*3;

# %%
data[['weekly_sales','fuel_price_usd_per_l']].agg(in2)
# Out:
# weekly_sales            5.137894e+08
# fuel_price_usd_per_l    1.615552e+04
# dtype: float64

# %%
data[['weekly_sales','fuel_price_usd_per_l']].agg(in3)
# Out:
# weekly_sales            7.706842e+08
# fuel_price_usd_per_l    2.423329e+04
# dtype: float64

# %%
data[['weekly_sales','fuel_price_usd_per_l']].agg([in2,in3])
# Out:
#      weekly_sales  fuel_price_usd_per_l
# in2   513789437.8          16155.523444
# in3   770684156.7          24233.285166

# %%
data['weekly_sales'].cumsum()
# Out:
# 0        2.492450e+04
# 1        4.675240e+04
# 2        1.040108e+05
# 3        1.214248e+05
# 4        1.389829e+05
#              ...
# 10769    2.568930e+08
# 10770    2.568934e+08
# 10771    2.568938e+08
# 10772    2.568938e+08
# 10773    2.568947e+08
# Name: weekly_sales, Length: 10774, dtype: float64

# %%
data['weekly_sales'].cummin()
# Out:
# 0        24924.50
# 1        21827.90
# 2        21827.90
# 3        17413.94
# 4        17413.94
#            ...
# 10769    -1098.00
# 10770    -1098.00
# 10771    -1098.00
# 10772    -1098.00
# 10773    -1098.00
# Name: weekly_sales, Length: 10774, dtype: float64

# %%
data['weekly_sales'].cumprod()
# Out:
# 0        2.492450e+04
# 1        5.440495e+08
# 2        3.115142e+13
# 3        5.424690e+17
# 4        9.524719e+21
#              ...
# 10769             NaN
# 10770             NaN
# 10771             NaN
# 10772             NaN
# 10773             NaN
# Name: weekly_sales, Length: 10774, dtype: float64

# %%
data
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 1               1      1    A           1  2010-03-05      21827.90
# 2               2      1    A           1  2010-04-02      57258.43
# 3               3      1    A           1  2010-05-07      17413.94
# 4               4      1    A           1  2010-06-04      17558.09
# ...           ...    ...  ...         ...         ...           ...
# 10769       10769     39    A          99  2011-12-09        895.00
# 10770       10770     39    A          99  2012-02-03        350.00
# 10771       10771     39    A          99  2012-06-08        450.00
# 10772       10772     39    A          99  2012-07-13          0.06
# 10773       10773     39    A          99  2012-10-05        915.00
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
data.drop_duplicates(subset=['date'])
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 1               1      1    A           1  2010-03-05      21827.90
# 2               2      1    A           1  2010-04-02      57258.43
# 3               3      1    A           1  2010-05-07      17413.94
# 4               4      1    A           1  2010-06-04      17558.09
# ...           ...    ...  ...         ...         ...           ...
# 9627         9627     31    A          60  2010-04-23          7.00
# 9693         9693     31    A          78  2010-09-17         -2.00
# 9694         9694     31    A          78  2011-10-28        -12.88
# 9890         9890     31    A          99  2011-04-22        100.00
# 10408       10408     39    A          47  2012-06-22         18.00
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
data.drop_duplicates(subset=['weekly_sales'])
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 1               1      1    A           1  2010-03-05      21827.90
# 2               2      1    A           1  2010-04-02      57258.43
# 3               3      1    A           1  2010-05-07      17413.94
# 4               4      1    A           1  2010-06-04      17558.09
# ...           ...    ...  ...         ...         ...           ...
# 10761       10761     39    A          98  2010-12-03       8980.72
# 10762       10762     39    A          98  2011-01-07       7666.71
# 10765       10765     39    A          99  2010-09-24        167.00
# 10767       10767     39    A          99  2011-08-19        622.00
# 10773       10773     39    A          99  2012-10-05        915.00
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
data.shape
# Out:
# (10774, 10)

# %%
subset=data.head(50)

# %%
subset
# Out:
#     Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0            0      1    A           1  2010-02-05      24924.50       False
# 1            1      1    A           1  2010-03-05      21827.90       False
# 2            2      1    A           1  2010-04-02      57258.43       False
# 3            3      1    A           1  2010-05-07      17413.94       False
# 4            4      1    A           1  2010-06-04      17558.09       False
# 5            5      1    A           1  2010-07-02      16333.14       False
# 6            6      1    A           1  2010-08-06      17508.41       False
# 7            7      1    A           1  2010-09-03      16241.78       False
# 8            8      1    A           1  2010-10-01      20094.19       False
# 9            9      1    A           1  2010-11-05      34238.88       False
# 10          10      1    A           1  2010-12-03      22517.56       False
# ...

# %%
subset['department'].value_counts(sort=True)
# Out:
# 4    12
# 3    12
# 2    12
# 1    12
# 5     2
# Name: department, dtype: int64

# %%
subset['department'].value_counts(normalize=True)
# Out:
# 4    0.24
# 3    0.24
# 2    0.24
# 1    0.24
# 5    0.04
# Name: department, dtype: float64

# %%
subset
# Out:
#     Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0            0      1    A           1  2010-02-05      24924.50       False
# 1            1      1    A           1  2010-03-05      21827.90       False
# 2            2      1    A           1  2010-04-02      57258.43       False
# 3            3      1    A           1  2010-05-07      17413.94       False
# 4            4      1    A           1  2010-06-04      17558.09       False
# 5            5      1    A           1  2010-07-02      16333.14       False
# 6            6      1    A           1  2010-08-06      17508.41       False
# 7            7      1    A           1  2010-09-03      16241.78       False
# 8            8      1    A           1  2010-10-01      20094.19       False
# 9            9      1    A           1  2010-11-05      34238.88       False
# 10          10      1    A           1  2010-12-03      22517.56       False
# ...

# %%
data
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 1               1      1    A           1  2010-03-05      21827.90
# 2               2      1    A           1  2010-04-02      57258.43
# 3               3      1    A           1  2010-05-07      17413.94
# 4               4      1    A           1  2010-06-04      17558.09
# ...           ...    ...  ...         ...         ...           ...
# 10769       10769     39    A          99  2011-12-09        895.00
# 10770       10770     39    A          99  2012-02-03        350.00
# 10771       10771     39    A          99  2012-06-08        450.00
# 10772       10772     39    A          99  2012-07-13          0.06
# 10773       10773     39    A          99  2012-10-05        915.00
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
data.groupby('store')['weekly_sales'].mean()
# Out:
# store
# 1     20896.941787
# 2     26517.435162
# 4     26126.986071
# 6     21561.186477
# 10    25696.678370
# 13    25664.149474
# 14    30384.003017
# 19    19930.838157
# 20    28382.766385
# 27    24207.474711
# 31    18178.932225
# 39    18414.938423
# Name: weekly_sales, dtype: float64

# %%
data.groupby('store')['weekly_sales'].agg([min,max,sum])
# Out:
#           min        max          sum
# store
# 1      -698.0  140504.41  18828144.55
# 2     -1098.0  178982.89  23786139.34
# 4       -88.0  165765.50  23540414.45
# 6      -698.0  119812.38  19275700.71
# 10     -798.0  232558.51  23178403.89
# 13      -98.0  166872.27  23431368.47
# 14     -498.0  293966.05  26889842.67
# 19     -449.0  147449.06  18057339.37
# 20     -598.0  195223.84  25828317.41
# 27     -409.0  177605.86  21786727.24
# 31     -224.0  131062.82  16179249.68
# 39     -159.0  114691.10  16113071.12

# %%
data.groupby('store')['weekly_sales'].agg([min,max,sum])
# Out:
#           min        max          sum
# store
# 1      -698.0  140504.41  18828144.55
# 2     -1098.0  178982.89  23786139.34
# 4       -88.0  165765.50  23540414.45
# 6      -698.0  119812.38  19275700.71
# 10     -798.0  232558.51  23178403.89
# 13      -98.0  166872.27  23431368.47
# 14     -498.0  293966.05  26889842.67
# 19     -449.0  147449.06  18057339.37
# 20     -598.0  195223.84  25828317.41
# 27     -409.0  177605.86  21786727.24
# 31     -224.0  131062.82  16179249.68
# 39     -159.0  114691.10  16113071.12

# %%
data.groupby(['store','department'])['weekly_sales','fuel_price_usd_per_l'].agg([min,max,sum])
# Out:
# <ipython-input-39-4510b8dd05a2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['store','department'])['weekly_sales','fuel_price_usd_per_l'].agg([min,max,sum])
#                  weekly_sales                        fuel_price_usd_per_l  \
#                           min        max         sum                  min
# store department
# 1     1              15984.24   57258.43   281901.06             0.679451
#       2              43202.29   50605.27   569053.49             0.679451
#       3               7857.88   26719.02   154471.08             0.679451
#       4              34912.45   40973.88   460587.07             0.679451
#       5              15390.52   36472.02   285133.44             0.679451
# ...                       ...        ...         ...                  ...
# 39    95             83451.22  114691.10  1166090.03             0.679451
# ...

# %%
data.groupby('store')['weekly_sales'].mean()
# Out:
# store
# 1     20896.941787
# 2     26517.435162
# 4     26126.986071
# 6     21561.186477
# 10    25696.678370
# 13    25664.149474
# 14    30384.003017
# 19    19930.838157
# 20    28382.766385
# 27    24207.474711
# 31    18178.932225
# 39    18414.938423
# Name: weekly_sales, dtype: float64

# %%
data.pivot_table(values="weekly_sales",index='store',aggfunc=np.mean)
# Out:
#        weekly_sales
# store
# 1      20896.941787
# 2      26517.435162
# 4      26126.986071
# 6      21561.186477
# 10     25696.678370
# 13     25664.149474
# 14     30384.003017
# 19     19930.838157
# 20     28382.766385
# 27     24207.474711
# 31     18178.932225
# 39     18414.938423

# %%
data.pivot_table(values="weekly_sales",index='store',aggfunc=np.median)
# Out:
#        weekly_sales
# store
# 1          9775.170
# 2         13764.940
# 4         13063.930
# 6         13200.780
# 10        13336.080
# 13        13050.060
# 14        14792.990
# 19        11091.770
# 20        14706.675
# 27        12689.850
# 31         7787.725
# 39         8980.720

# %%
data
# Out:
#        Unnamed: 0  store type  department        date  weekly_sales  \
# 0               0      1    A           1  2010-02-05      24924.50
# 1               1      1    A           1  2010-03-05      21827.90
# 2               2      1    A           1  2010-04-02      57258.43
# 3               3      1    A           1  2010-05-07      17413.94
# 4               4      1    A           1  2010-06-04      17558.09
# ...           ...    ...  ...         ...         ...           ...
# 10769       10769     39    A          99  2011-12-09        895.00
# 10770       10770     39    A          99  2012-02-03        350.00
# 10771       10771     39    A          99  2012-06-08        450.00
# 10772       10772     39    A          99  2012-07-13          0.06
# 10773       10773     39    A          99  2012-10-05        915.00
#
#        is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0           False       5.727778              0.679451         8.106
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
data.groupby(['department','type']).mean()
# Out:
#                   Unnamed: 0      store   weekly_sales  is_holiday  \
# department type
# 1          A     5079.136364  16.000000   30961.725379     0.00000
#            B     3598.500000  10.000000   44050.626667     0.00000
# 2          A     5091.136364  16.000000   67600.158788     0.00000
#            B     3610.500000  10.000000  112958.526667     0.00000
# 3          A     5103.136364  16.000000   17160.002955     0.00000
# ...                      ...        ...            ...         ...
# 97         A     5941.409091  16.000000   28471.266970     0.00000
#            B     4476.500000  10.000000    5828.873333     0.00000
# 98         A     5953.409091  16.000000   12875.423182     0.00000
#            B     4488.500000  10.000000     217.428333     0.00000
# 99         A     5992.349593  16.097561     379.123659     0.03252
#
#                  temperature_c  fuel_price_usd_per_l  unemployment
# department type
# ...

# %%
data.pivot_table(columns="department",index="type",aggfunc=[np.mean,np.median],values="weekly_sales")
# Out:
#                     mean                                             \
# department            1              2             3             4
# type
# A           30961.725379   67600.158788  17160.002955  44285.399091
# B           44050.626667  112958.526667  30580.655000  51219.654167
#
#                                                                     \
# department            5             6             7             8
# type
# A           34821.011364   7136.292652  38454.336818  48583.475303
# B           63236.875000  10717.297500  52909.653333  90733.753333
#
#                                         ...     median                        \
# department            9             10  ...         90         91         92
# type                                    ...
# A           30120.449924  30930.456364  ...  82396.385  67424.590  140013.13
# B           66679.301667  48595.126667  ...  14738.245  12950.435   50694.95
#
# ...

# %%
data.groupby(['store','department'])['weekly_sales','fuel_price_usd_per_l'].agg([min,max,sum])
# Out:
# <ipython-input-47-4510b8dd05a2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['store','department'])['weekly_sales','fuel_price_usd_per_l'].agg([min,max,sum])
#                  weekly_sales                        fuel_price_usd_per_l  \
#                           min        max         sum                  min
# store department
# 1     1              15984.24   57258.43   281901.06             0.679451
#       2              43202.29   50605.27   569053.49             0.679451
#       3               7857.88   26719.02   154471.08             0.679451
#       4              34912.45   40973.88   460587.07             0.679451
#       5              15390.52   36472.02   285133.44             0.679451
# ...                       ...        ...         ...                  ...
# 39    95             83451.22  114691.10  1166090.03             0.679451
# ...

# %%
data.pivot_table(index='store',columns='department',aggfunc=[min,max,sum],values="weekly_sales")
# Out:
#                  min                                                    \
# department        1          2         3         4         5        6
# store
# 1           15984.24   43202.29   7857.88  34912.45  15390.52  1376.15
# 2           19092.94   62758.12  11663.03  44705.44  23507.43  2969.62
# 4           24769.54   83294.12   9791.98  54037.74  31085.72  4760.80
# 6           13951.76   43966.75  10022.95  28762.65  24077.30  3948.80
# 10          26041.71  104127.28  20011.47  44664.92  38887.81  6773.01
# 13          24627.06   69822.04  14332.61  38712.93  34784.77  4380.95
# 14          13527.45   70335.01  11057.98  52124.33  27107.95  4898.19
# 19           9446.29   42431.88   9623.14  29792.17  22607.32  4796.85
# 20          24790.50   73125.57   9459.43  51233.71  30189.58  2168.97
# 27          17654.48   56202.44  10800.45  31348.88  24230.65  4741.58
# 31          11953.28   50361.17   6150.20  30308.10  11665.55  1949.94
# ...
